# %% [markdown]
# ## WHAT IS PYTHON

# %%
#1- python is  simple & esay language.
#2- free & open source.
#3- high level language.
#4- developed by Guido van Rossum.
#5- portable.

# %%
print("hello world")
# Out:
# hello world

# %%
print("hello aryan")
# Out:
# hello aryan

# %%
print("madhurima singh")
# Out:
# madhurima singh

# %%
name1='rn'
name2="rn"
name3='''rn'''
name4="'rn'"

# %%
print(name1)
print(name2)
print(name3)
print(name4)
# Out:
# rn
# rn
# rn
# 'rn'

# %% [markdown]
# ## PYTHON CHARACTER SET

# %%
#1- letter- a to z,A to Z.
#2- digits- 0 to 9.
#3- special symbols +,-,/,*,//,.
#4- white spaces-blank space,tab,carriage return,newline,formfeed.
#5- other character- python can process all ASCII and unicode character as part of data or  literals.

# %%
print("my name is madhurima singh,i am 18 year old")
# Out:
# my name is madhurima singh,i am 18 year old

# %%
print("my name is madhurima singh.","i am 18 year old.")
# Out:
# my name is madhurima singh. i am 18 year old.

# %%
print("aryan singh")
# Out:
# aryan singh

# %%
print("deepa singh")
# Out:
# deepa singh

# %%
print("i love my mummy & papa.")
# Out:
# i love my mummy & papa.

# %%
print(244)
# Out:
# 244

# %%
print(3333)
# Out:
# 3333

# %%
print(373+727)
# Out:
# 1100

# %%
print(838-732)
# Out:
# 106

# %%
print(6732*73)
# Out:
# 491436

# %%
print(24432/2)
# Out:
# 12216.0

# %%
print(7632//4)
# Out:
# 1908

# %%
print(6326%763)
# Out:
# 222

# %% [markdown]
# ## VARIABLES

# %%
#A variable is a name given to a memory location in a pythhon.
#variable=value

# %%
name="madhurima singh"    # string
age=18   # int
price=25.99  #float

# %%
print("name")
# Out:
# name

# %%
print(name)
# Out:
# madhurima singh

# %%
print("age")
# Out:
# age

# %%
print(age)
# Out:
# 18

# %%
print("price")
# Out:
# price

# %%
print(price)
# Out:
# 25.99

# %%
print("my name is :",name)
# Out:
# my name is : madhurima singh

# %%
print("my  age is :",age)
# Out:
# my  age is : 18

# %%
name="madhurima singh"
age=18
price=25.99
age2=age

# %%
print(age2)
# Out:
# 18

# %% [markdown]
# ## RULES FOR  IDENTIFIERS

# %%
#1- identifiers can be combination of uppercase and lowercase letter,digit or an underscore(_).
#so Myvariable,variable_1,variable_for-print all are valid python identifiers.
#2- an  identifier can not start with digit. so while variable1 is valid 1variable is not  valid.
#3- we can not use special symbols  like !,@,#,$,% etc in our identifier.
#4- identifier can be of any length.

# %%
name="madhurima singh"
age=18
price=25.99

# %%
print(type(name))
print(type(age))
print(type(price))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %% [markdown]
# ## DATA TYPE

# %%
#1- integers      # +ve,-ve,0
#2- string        # a to z,(" "),(''' '''),(' ')
#3- float         # 23.33,33.5,54.6
#4- boolean       # True,False
#5- None

# %%
age=23
old=False
a=None

# %%
print(type(old))
print(type(a))
# Out:
# <class 'bool'>
# <class 'NoneType'>

# %% [markdown]
# ## KEYWORDS

# %%
keywords are reserved words in python.

# %%
"""1. and                                                               19. import
2. as                                                                20. in
3. assert                                                            21. is
4. async                                                             22. lambda
5. await                                                             23. nonlocal
6. break                                                             24. not
7. class                                                             25. or
8. continue                                                          26. pass  
9. def                                                               27. raise
10. del                                                              28. return
11. elif                                                             29. try
12. else                                                             30. while
13. except                                                           31. with
14. finally                                                          32. yield
15. for                                                              33. True
16. from                                                             34. False
17. global                                                           35. None
18. if"""

# %% [markdown]
# ## sum

# %%
a=2
b=5
sum=a+b
print(sum)
# Out:
# 7

# %%
a=1000
b=500
sum=a+b
print(sum)
# Out:
# 1500

# %%
a=232
b=342
sum=a+b
print(sum)
# Out:
# 574

# %% [markdown]
# ## SUBTRACTING

# %%
a=213
b=212
sub=(a-b)
print(sub)
# Out:
# 1

# %%
a=123123
b=34563
sub=(a-b)
print(sub)
# Out:
# 88560

# %%
a=233
b=453
sub=(a-b)
print(sub)
# Out:
# -220

# %% [markdown]
# ## MULTIPLICATION

# %%
a=232
b=23
mul=(a*b)
print(mul)
# Out:
# 5336

# %%
a=1213
b=543
mul=(a*b)
print(mul)
# Out:
# 658659

# %%
a=6332
b=4324
mul=(a*b)
print(mul)
# Out:
# 27379568

# %% [markdown]
# ## division

# %%
a=345
b=3
div=(a/b)
print(div)
# Out:
# 115.0

# %%
a=10000
b=5
div=(a/b)
print(div)
# Out:
# 2000.0

# %%
a=783732
b=42
div=(a/b)
print(div)
# Out:
# 18660.285714285714

# %% [markdown]
# ## COMMENTS IN PYTHON

# %%
# single line comment
"""
multi line
comment 
"""
print("madhurima singh")
# Out:
# madhurima singh

# %%
"""
multi line
comment 
"""
print("madhurima singh")
# Out:
# madhurima singh

# %%
print("madhurima singh")
"""
multi line
comment 
"""
# Out:
# madhurima singh
# '\nmulti line\ncomment \n'

# %%
print("madhurima singh")
#print("madhurima singh")
#print("madhurima singh")
#print("madhurima singh")
# Out:
# madhurima singh

# %%
print("madhurima singh")
"""
print("madhurima singh")
print("madhurima singh")
print("madhurima singh")
"""
# Out:
# madhurima singh
# '\nprint("madhurima singh")\nprint("madhurima singh")\nprint("madhurima singh")\n'

# %%
"""
print("madhurima singh")
print("madhurima singh")
print("madhurima singh")
"""
print("madhurima singh")
# Out:
# madhurima singh

# %%
## TYPE OF OPERATORS

# %%
#An operator is a symbol that performs a certain operation between operands.

# %%
#1- Arithmetic operators (-,+,*,/,** ,%)
#2- Relational/comparison operators (==,!=,<,>,>=,<=)
#3- Assignment operators (+=,-=,*=,/=,%=,**=,=)                                       
#4- Logical operatos (not,and,or)

# %% [markdown]
# ## ARITHMETIC OPEATORS

# %%
a=73
b=732
print(a+b)
# Out:
# 805

# %%
a=73
b=732
sum=a+b
print(sum)
# Out:
# 805

# %%
a=5632
b=673
sum=a+b
print(sum)
# Out:
# 6305

# %%
a=62
b=236
sum=a+b
print(sum)
# Out:
# 298

# %%
a=62766
b=2657
sum=a+b
print(sum)
# Out:
# 65423

# %%
a=27637264
b=83548758
sum=a+b
print(sum)
# Out:
# 111186022

# %%
a=7674
b=7126
sub=(a-b)
print(sub)
# Out:
# 548

# %%
a=63532
b=2763
sub=(a-b)
print(sub)
# Out:
# 60769

# %%
a=378347
b=6363
sub=(a-b)
print(sub)
# Out:
# 371984

# %%
a=237
b=66
sub=(a-b)
print(sub)
# Out:
# 171

# %%
a=34345
b=5467
sub=(a-b)
print(sub)
# Out:
# 28878

# %%
a=773
b=7834
mul=(a*b)
print(mul)
# Out:
# 6055682

# %%
a=3645
b=355
mul=(a*b)
print(mul)
# Out:
# 1293975

# %%
a=34556
b=563456
mul=(a*b)
print(mul)
# Out:
# 19470785536

# %%
a=34567
b=345456
mul=(a*b)
print(mul)
# Out:
# 11941377552

# %%
a=33454657
b=34567
mul=(a*b)
print(mul)
# Out:
# 1156427128519

# %%
a=5567
b=322
div=(a/b)
print(div)
# Out:
# 17.288819875776397

# %%
a=236555
b=434
div=(a/b)
print(div)
# Out:
# 545.057603686636

# %%
a=5656
b=2
div=(a/b)
print(div)
# Out:
# 2828.0

# %%
a=334657
b=345
div=(a/b)
print(div)
# Out:
# 970.0202898550725

# %%
a=26343546
b=324567
div=(a/b)
print(div)
# Out:
# 81.16520163787446

# %%
a=345
b=5
div=(a/b)
print(div)
# Out:
# 69.0

# %% [markdown]
# ##  MODULUS

# %%
a=3243545
b=45
mod=(a%b)
print(mod)
# Out:
# 35

# %%
a=57687877832
b=22
mod=(a%b)
print(mod)
# Out:
# 2

# %%
a=676637
b=234
mod=(a%b)
print(mod)
# Out:
# 143

# %%
a=732345
b=55
mod=(a%b)
print(mod)
# Out:
# 20

# %%
a=3674675
b=3545
mod=(a%b)
print(mod)
# Out:
# 2055

# %% [markdown]
# ## EXPONENTIATION

# %%
a=5
b=2
exp=(a**b)
print(exp)
# Out:
# 25

# %%
a=7
b=3
exp=(a**b)
print(exp)
# Out:
# 343

# %%
a=6
b=4
exp=(a**b)
print(exp)
# Out:
# 1296

# %%
a=12
b=2
exp=(a**b)
print(exp)
# Out:
# 144

# %%
a=13
b=3
exp=(a**b)
print(exp)
# Out:
# 2197

# %% [markdown]
# ## RELATIONAL/COMPARISON OPERATORS

# %%
a=23
b=55
print(a==b)
# Out:
# False

# %%
a=55
b=55
print(a==b)
# Out:
# True

# %%
a=272434
b=28373
print(a==b)
# Out:
# False

# %%
a=272434
b=272434
print(a==b)
# Out:
# True

# %%
a=123566
b=565768
print(a==b)
# Out:
# False

# %%
a=123566
b=123566
print(a==b)
# Out:
# True

# %%
a=1345
b=23456
print(a==b)
# Out:
# False

# %%
a=1345
b=1345
print(a==b)
# Out:
# True

# %%
a=12356
b=23456
print(a==b)
# Out:
# False

# %%
a=12356
b=12356
print(a==b)
# Out:
# True

# %%
a=12356
b=23456
print(a!=b)
# Out:
# True

# %%
a=12356
b=23456
print(a==b)
# Out:
# False

# %%
a=12356
b=12356
print(a!=b)
# Out:
# False

# %%
a=12356
b=23456
print(a==b)
# Out:
# False

# %%
a=12356
b=23456
print(a!=b)
# Out:
# True

# %%
a=1345
b=1345
print(a==b)
# Out:
# True

# %%
a=1345
b=1345
print(a!=b)
# Out:
# False

# %%
a=123566
b=123566
print(a==b)
# Out:
# True

# %%
a=123566
b=123566
print(a!=b)
# Out:
# False

# %%
a=272434
b=272434
print(a==b)
# Out:
# True

# %%
a=272434
b=272434
print(a!=b)
# Out:
# False

# %%
a=272434
b=28373
print(a==b)
# Out:
# False

# %%
a=272434
b=28373
print(a!=b)
# Out:
# True

# %%
a=23
b=55
print(a!=b)
# Out:
# True

# %%
a=23
b=55
print(a==b)
# Out:
# False

# %%
a=55
b=55
print(a==b)
# Out:
# True

# %%
a=55
b=55
print(a!=b)
# Out:
# False

# %%
a=55
b=55
print(a>b)
# Out:
# False

# %%
a=55
b=55
print(a>=b)
# Out:
# True

# %%
a=55
b=55
print(a<b)
# Out:
# False

# %%
a=55
b=55
print(a<=b)
# Out:
# True

# %%
a=23
b=55
print(a<b)
# Out:
# True

# %%
a=23
b=55
print(a<=b)
# Out:
# True

# %%
a=23
b=55
print(a>b)
# Out:
# False

# %%
a=23
b=55
print(a>=b)
# Out:
# False

# %% [markdown]
# ## ASSIGNMENT OPERATORS

# %%
num=10
num=num+10
print(num)
# Out:
# 20

# %%
num=10
num+=10
print(num)
# Out:
# 20

# %%
num=10
num=num+10
print("num:",num)
# Out:
# num: 20

# %%
num=10
num+=10
print("num:",num)
# Out:
# num: 20

# %%
num=233
num+=5466
print(num)
# Out:
# 5699

# %%
num=233
num+=5466
print("num:",num)
# Out:
# num: 5699

# %%
num=23456
num+=12356
print(num)
# Out:
# 35812

# %%
num=23456
num+=12356
print("num:",num)
# Out:
# num: 35812

# %%
num=3245678
num+=34565768
print(num)
# Out:
# 37811446

# %%
num=3245678
num+=34565768
print("num:",num)
# Out:
# num: 37811446

# %%
num=2345678
num+=1234567
print(num)
# Out:
# 3580245

# %%
num=2345678
num+=1234567
print("num:",num)
# Out:
# num: 3580245

# %%
num=23456
num+=234567
print(num)
# Out:
# 258023

# %%
num=23456
num+=234567
print("num:",num)
# Out:
# num: 258023

# %%
num=2134567
num-=23456
print(num)
# Out:
# 2111111

# %%
num=2134567
num-=23456
print("num:",num)
# Out:
# num: 2111111

# %%
num=345678
num-=345678
print(num)
# Out:
# 0

# %%
num=345678
num-=345678
print("num:",num)
# Out:
# num: 0

# %%
num=234567
num-=234567
print(num)
# Out:
# 0

# %%
num=234567
num-=234567
print("num:",num)
# Out:
# num: 0

# %%
num=12345678
num-=456789
print(num)
# Out:
# 11888889

# %%
num=12345678
num-=456789
print("num:",num)
# Out:
# num: 11888889

# %%
num=34567
num-=4356
print(num)
# Out:
# 30211

# %%
num=34567
num-=4356
print("num:",num)
# Out:
# num: 30211

# %%
num=3462
num*=444567
print(num)
# Out:
# 1539090954

# %%
num=3462
num*=444567
print("num::",num)
# Out:
# num:: 1539090954

# %%
num=3245678
num*=5678
print(num)
# Out:
# 18428959684

# %%
num=3245678
num*=5678
print("num:",num)
# Out:
# num: 18428959684

# %%
num=234567
num*=345
print(num)
# Out:
# 80925615

# %%
num=234567
num*=345
print("num:",num)
# Out:
# num: 80925615

# %%
num=345678
num*=445678
print(num)
# Out:
# 154061079684

# %%
num=345678
num*=445678
print("num:",num)
# Out:
# num: 154061079684

# %%
num=3456
num*=345
print(num)
# Out:
# 1192320

# %%
num=3456
num*=345
print("num:",num)
# Out:
# num: 1192320

# %%
num=23456
num/=2
print(num)
# Out:
# 11728.0

# %%
num=23456
num/=2
print("num:",num)
# Out:
# num: 11728.0

# %%
num=324567
num/=456
print(num)
# Out:
# 711.7697368421053

# %%
num=324567
num/=456
print("num:",num)
# Out:
# num: 711.7697368421053

# %%
num=2236566
num/=123
print(num)
# Out:
# 18183.463414634145

# %%
num=2236566
num/=123
print("num:",num)
# Out:
# num: 18183.463414634145

# %%
num=4335678
num/=6577
print(num)
# Out:
# 659.2181845826365

# %%
num=4335678
num/=6577
print("num:",num)
# Out:
# num: 659.2181845826365

# %%
num=23456
num/=2
print(num)
# Out:
# 11728.0

# %%
num=23456
num/=2
print("num:",num)
# Out:
# num: 11728.0

# %%
num=34567
num**=12
print(num)
# Out:
# 2910316862685022448630906200127482280301826230298006561

# %%
num=34567
num**=12
print("num:",num)
# Out:
# num: 2910316862685022448630906200127482280301826230298006561

# %%
num=657
num**=5
print(num)
# Out:
# 122412804495057

# %%
num=657
num**=5
print("num:",num)
# Out:
# num: 122412804495057

# %%
num=3456
num**=3
print(num)
# Out:
# 41278242816

# %%
num=3456
num**=3
print("num:",num)
# Out:
# num: 41278242816

# %%
num=3456
num**=3
print(num)

# %%
num=3456
num**=3
print("num:",num)
# Out:
# num: 41278242816

# %%
num=4
num**=4
print(num)
# Out:
# 256

# %%
num=4
num**=4
print("num:",num)
# Out:
# num: 256

# %%
num=345456
num%=32
print(num)
# Out:
# 16

# %%
num=345456
num%=32
print("num:",num)
# Out:
# num: 16

# %%
num=44356575
num%=5
print(num)
# Out:
# 0

# %%
num=44356575
num%=5
print("num:",num)
# Out:
# num: 0

# %%
num=3245678
num%=8
print(num)
# Out:
# 6

# %%
num=3245678
num%=8
print("num:",num)
# Out:
# num: 6

# %%
num=32454657
num%=467
print(num)
# Out:
# 25

# %%
num=32454657
num%=467
print("num:",num)
# Out:
# num: 25

# %%
num=32456
num%=54
print(num)
# Out:
# 2

# %%
num=32456
num%=54
print("num:",num)
# Out:
# num: 2

# %% [markdown]
# ## LOGICAL OPERATORS

# %%
print(not False)
# Out:
# True

# %%
print(not True)
# Out:
# False

# %%
a=50
b=20
print(a>b)
# Out:
# True

# %%
a=50
b=20
print(not(a>b))
# Out:
# False

# %%
num1=8
num2=8
print("and operator:",num1 and num2)
# Out:
# and operator: 8

# %%
num1=True
num2=True
print("and operator:",num1 and num2)
# Out:
# and operator: True

# %%
num1=False
num2=False
print("and operator:",num1 and num2)
# Out:
# and operator: False

# %%
num1=False
num2=True
print("and operator:",num1 and num2)
# Out:
# and operator: False

# %%
num1=True
num2=False
print("and operator:",num1 and num2)
# Out:
# and operator: False

# %%
a=50
b=30
print("and operator:",(a==b) and (a<b))
# Out:
# and operator: False

# %%
a=50
b=30
print("and operator:",(a==b) and (a<=b))
# Out:
# and operator: False

# %%
a=50
b=30
print("and operator:",(a==b) and (a>b))
# Out:
# and operator: False

# %%
a=50
b=30
print("and operator:",(a==b) and (a>=b))
# Out:
# and operator: False

# %%
a=50
b=30
print("and operator:",(a!=b) and (a<b))
# Out:
# and operator: False

# %%
a=50
b=30
print("and operator:",(a!=b) and (a<=b))
# Out:
# and operator: False

# %%
a=50
b=30
print("and operator:",(a!=b) and (a>b))
# Out:
# and operator: True

# %%
a=50
b=30
print("and operator:",(a!=b) and (a>=b))
# Out:
# and operator: True

# %%
num1=8
num2=8
print("or operator:",num1 or num2)
# Out:
# or operator: 8

# %%
num1=True
num2=True
print("or operator:",num1 or num2)
# Out:
# or operator: True

# %%
num1=False
num2=False
print("or operator:",num1 or num2)
# Out:
# or operator: False

# %%
num1=False
num2=True
print("or operator:",num1 or num2)
# Out:
# or operator: True

# %%
num1=True
num2=False
print("or operator:",num1 or num2)
# Out:
# or operator: True

# %%
a=50
b=30
print("or operator:",(a==b) or (a<b))
# Out:
# or operator: False

# %%
a=50
b=30
print("or operator:",(a==b) or (a>b))
# Out:
# or operator: True

# %%
a=50
b=30
print("or operator:",(a!=b) or (a>b))
# Out:
# or operator: True

# %%
a=50
b=30
print("or operator:",(a!=b) or (a<b))
# Out:
# or operator: True

# %%
a=50
b=30
print("or operator:",(a==b) or (a>=b))
# Out:
# or operator: True

# %%
a=50
b=30
print("or operator:",(a==b) or (a<=b))
# Out:
# or operator: False

# %%
a=50
b=30
print("or operator:",(a!=b) or (a>=b))
# Out:
# or operator: True

# %%
a=50
b=30
print("or operator:",(a!=b) or (a<=b))
# Out:
# or operator: True

# %% [markdown]
# ## TYPE CONVERSION

# %%
a=2
b=22.4
sum=a+b
print(sum)
# Out:
# 24.4

# %%
a=32
b=123.11234
sum=a+b
print(sum)
# Out:
# 155.11234000000002

# %%
a=456
b=123.2345
sum=a+b
print(sum)
# Out:
# 579.2345

# %%
a=4567.456
b=4567
sum=a+b
print(sum)
# Out:
# 9134.456

# %% [markdown]
# ## INPUT IN PYTHON

# %%
#input () statement is used to accept values (using keyboard) from user.
#input ()  # result for input () is always a str.
#int (input())   # int
#float (input())   # float"""

# %%
name=input("enter your name:")
# Out:
# enter your name: madhurima singh

# %%
name=input("my name is:")
print("welcome",name)
# Out:
# my name is: aryan singh
# welcome aryan singh

# %%
val=input("enter some value:")
print(type(val),val)
# Out:
# enter some value: 25
# <class 'str'> 25

# %%
val=input("enter some value:")
print(type(val),val)
# Out:
# enter some value: madhurima singh
# <class 'str'> madhurima singh

# %%
val=input("enter some value:")
print(type(val),val)
# Out:
# enter some value: 2134.23
# <class 'str'> 2134.23

# %%
val=float (input("enter some value:"))
print(type(val),val)
# Out:
# enter some value: 234
# <class 'float'> 234.0

# %%
val=int(input("enter some value:"))
print(type(val),val)
# Out:
# enter some value: 213
# <class 'int'> 213

# %%
name=input("enter name:")
age=input("enter age:")
marks=input("enter marks:")
print("welcome",name)
print("age=",age)
print("marks=",marks)
# Out:
# enter name: madhurima singh
# enter age: 18
# enter marks: 78.5
# welcome madhurima singh
# age= 18
# marks= 78.5

# %%
name=input("enter name:")
marks=float(input("enter marks:"))
age=int(input("enter age:"))
# Out:
# enter name: madhurima singh
# enter marks: 78.5
# enter age: 18

# %%
name=input("enter name:")
marks=float(input("enter marks:"))
age=int(input("enter age:"))
print(type(name),name)
# Out:
# enter name: aryan singh
# enter marks: 78.56
# enter age: 17
# <class 'str'> aryan singh
