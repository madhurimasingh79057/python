# %% [markdown]
# ## STRINGS

# %%
string is a data type that stores a sequence of characters.

# %%
str1="my name is madhurima singh"
str2='my name is madhurima singh'
str3='''my name is madhurima singh'''
str4="""my name is madhurima singh"""
print(str1)
print(str2)
print(str3)
print(str4)
# Out:
# my name is madhurima singh
# my name is madhurima singh
# my name is madhurima singh
# my name is madhurima singh

# %%
# basic operations
1- concatenation
"hello" + "world" ---> "helloworld"
2- len of str
len(str)

# %%
str1="madhurima"
str2="singh"
print(str1+str2)
# Out:
# madhurimasingh

# %%
str1="madhurima"
str2="singh"
final_str=str1+" "+str2
print(final_str)
print(type(final_str))
# Out:
# madhurima singh
# <class 'str'>

# %%
str1="madhurima"
str2="singh"
final_str=str1+str2
print(final_str)
# Out:
# madhurimasingh

# %%
str1="my name is madhurima singh"
print(len(str1))
# Out:
# 26

# %%
str1="my name is madhurima singh.i am from amethi"
print(len(str1))
# Out:
# 43

# %%
str3="this is apnacollege's tutorial"
print(len(str3))
# Out:
# 30

# %%
'this is apnacollege's tutorial'
# this is wrong
# Out:
#   Cell In[2], line 1
#     'this is apnacollege's tutorial'
#                                    ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
" this is apnacollege's tutorial"
# this is right
# Out:
# " this is apnacollege's tutorial"

# %%
str1="my name is madhurima singh.i am from amethi"
print(str1)
# same line
# Out:
# my name is madhurima singh.i am from amethi

# %%
str1="my name is madhurima singh\ni am from amethi"
print(str1)
# next line
# Out:
# my name is madhurima singh
# i am from amethi

# %%
str1="my name is madhurima singh\n  i am from amethi"
print(str1)
# Out:
# my name is madhurima singh
#   i am from amethi

# %%
str1="madhurima"
str2="singh"
final_str=str1+str2
print(len(final_str))
# Out:
# 14

# %%
str1="madhurima"
str2="singh"
final_str=str1+" "+str2
print(len(final_str))
# Out:
# 15

# %% [markdown]
# ## INDEXING

# %%
m a d h u r i m a  
1 2 3 4 5 6 7 8 9

# %%
name="madhurima singh"
print(name[1])
# Out:
# a

# %%
print(name[9])

# %%
print(name[6])
# Out:
# i

# %%
print(name[0])
# Out:
# m

# %%
print(name[4])
# Out:
# u

# %%
name="madhurima singh"
ch=name[6]
print(ch)
# Out:
# i

# %% [markdown]
# ## SLICING

# %%
Accessing parts of a string.
str[string_idx : ending_idx]      # ending idx is not included

# %%
name="madhurima singh"
print(name[1:5])
# Out:
# adhu

# %%
print(name[4:9])
# Out:
# urima

# %%
print(name[0:5])
# Out:
# madhu

# %%
print(name[0:15])
# Out:
# madhurima singh

# %%
print(name[0:9])
# Out:
# madhurima

# %%
print(name[0:len(name)])
# Out:
# madhurima singh

# %%
print(name[9:len(name)])
# Out:
#  singh

# %%
print(name[0:])
# Out:
# madhurima singh

# %%
print(name[9:])
# Out:
#  singh

# %%
print(name[:9])
# Out:
# madhurima

# %% [markdown]
# ## NEGATIVE INDEX

# %%
name="madhurima singh"
print(name[-9:-1])
# Out:
# ima sing

# %%
print(name[-16:-1])
# Out:
# madhurima sing

# %%
print(name[-14:])
# Out:
# adhurima singh

# %%
print(name[-15:])
# Out:
# madhurima singh

# %%
print(name[-6:])
# Out:
#  singh

# %% [markdown]
# ## STRING FUNCTIONS

# %%
str="i am studying python  from apna college"
print(str.endswith("ege"))
# Out:
# True

# %%
print(str.endswith("age"))
# Out:
# False

# %%
str="i am studying python from apna college"
print(str.capitalize())
# Out:
# I am studying python from apna college

# %%
str="i am studying python from apna college"
print(str.capitalize())
print(str)
# Out:
# I am studying python from apna college
# i am studying python from apna college

# %%
str="i am studying python from apna college"
str=str.capitalize()
print(str)
# Out:
# I am studying python from apna college

# %%
str="i am studying python from apna college"
print(type(str))
# Out:
# <class 'str'>

# %%
str="I am studying python from apna college"
str=str.upper()
print(str)
# Out:
# I AM STUDYING PYTHON FROM APNA COLLEGE

# %%
str="I am studying python from apna college"
str=str.upper()
print(str)

# %%
str="i am studying python from apna college"
print(str.replace("o","a"))
# Out:
# i am studying pythan fram apna callege

# %%
str="i am studying python from apna college"
print(str.replace("a","o"))
# Out:
# i om studying python from opno college

# %%
str="i am studying python from apna college"
print(str.replace("python","javascript"))
# Out:
# i am studying javascript from apna college

# %%
str="i am studying python from apna college"
print(str.find("o"))
# Out:
# 18

# %%
str="i am from studying python from apna college" 
print(str.find("from"))
# Out:
# 5

# %%
print(str.find("q"))
# Out:
# -1

# %%
print(str.find("m"))
# Out:
# 3

# %%
print(str.find("z"))
# Out:
# -1

# %%
str="i am studying python from apna college"
print(str.count("am"))
# Out:
# 1

# %%
str="i am studying python from apna college"
print(str.count("studying"))
# Out:
# 1

# %%
print(str.count("o"))
# Out:
# 3

# %%
print(str.count("from"))
# Out:
# 1

# %%
str="i am from studying python from apna college"
print(str.count("from"))
# Out:
# 2

# %%
print(str.count("o"))
# Out:
# 4

# %%
print(str.count("m"))
# Out:
# 3

# %% [markdown]
# ## LET'S PRACTICE

# %%
#write a python to input users name & print its length.

# %%
name=input("enter your name:")
# Out:
# enter your name: madhurima singh

# %%
name=input("enter your name:")
print("length of your name is",len(name))
# Out:
# enter your name: madhurima singh
# length of your name is 15

# %%
name=input("enter your name :")
print("lenght of your name is",len(name))
# Out:
# enter your name : aryan singh
# lenghtof your name is 11

# %%
# write a python to find the occurrence of $ in a string.
str="Hi,$ i am the $ symbol $99.99"
print(str.count("$"))
# Out:
# 3

# %% [markdown]
# ## CONDITIONAL STATMENTS

# %%
# if-elif-else(syntax)
if(condition):
    statement1
elif(condition):
    statement2              # indentation {}
else:
    statamentN

# %%
age=21
if(age>=18):
    print("can vote & apply for license")
# Out:
# can vote & apply for license

# %%
age=24
if(age>=18):
    print("can vote")
    print("can drive")
# Out:
# can vote
# can drive

# %%
light="red"
if(light=="red"):
    print("stop")
elif(light=="green"):
    print("go")
elif(light=="yellow"):
    print("look")
# Out:
# stop

# %%
light="yellow"
if(light=="red"):
    print("stop")
elif(light=="green"):
    print("go")
elif(light=="yellow"):
    print("look")
# Out:
# look

# %%
light="green"
if(light=="red"):
    print("stop")
elif(light=="green"):
    print("go")
elif(light=="yellow"):
    print("look")
# Out:
# go

# %%
light="pink"
if(light=="red"):
    print("stop")
elif(light=="green"):
    print("go")
elif(light=="yellow"):
    print("look")
else:
    print("light is broken")
# Out:
# light is broken

# %%
light="yellow"
if(light=="red"):
    print("stop")
elif(light=="green"):
    print("go")
elif(light=="yellow"):
    print("look")
else:
    print("light is broken")
# Out:
# look

# %%
light="green"
if(light=="red"):
    print("stop")
elif(light=="green"):
    print("go")
elif(light=="yellow"):
    print("look")
else:
    print("light is broken")
# Out:
# go

# %%
num=5
if(num>3):
    print("yes")
elif(num<5):
    print("no")
# Out:
# yes

# %%
num=2
if(num>3):
    print("yes")
elif(num<5):
    print("no")
# Out:
# no

# %%
num=5
if (num>2):
    print("greater than 2")
elif(num>3):
    print("greater than 3")
# Out:
# greater than 2

# %%
num=8
if (num>6):
    print("greater than 2")
elif(num>7):
    print("greater than 3")
# Out:
# greater than 2

# %%
age=24
if(age>=18):
    print("can vote")
else:
    print("cannot vote")
# Out:
# can vote

# %%
age=14
if(age>=18):
    print("can vote")
else:
    print("cannot vote")
# Out:
# cannot vote

# %% [markdown]
# ## CONDITIONAL STATEMENTS

# %%
# grade students based on marks.
marks=74
if(marks>=90):
    grade="A"
elif(marks>=80 and marks<90):
    grade="B"
elif(marks>=70 and marks<80):
    grade="c"
else:
    grade="d"
print("grade of the student ->",grade)
# Out:
# grade of the student -> c

# %%
marks=int(input("enter the number"))
if(marks>=90):
    grade="A"
elif(marks>=80 and marks<90):
    grade="B"
elif(marks>=70 and marks<80):
    grade="c"
else:
    grade="d"
print("grade of the student ->",grade)
# Out:
# enter the number 90
# grade of the student -> A

# %%
marks=int(input("enter the number"))
if(marks>=90):
    grade="A"
elif(marks>=80 and marks<90):
    grade="B"
elif(marks>=70 and marks<80):
    grade="c"
else:
    grade="d"
print("grade of the student ->",grade)
# Out:
# enter the number 80
# grade of the student -> B

# %%
marks=int(input("enter the number:"))
if(marks>=90):
    grade="A"
elif(marks>=80 and marks<90):
    grade="B"
elif(marks>=70 and marks<80):
    grade="c"
else:
    grade="d"
print("grade of the student ->",grade)
# Out:
# enter the number: 70
# grade of the student -> c

# %%
marks=int(input("enter the number"))
if(marks>=90):
    grade="A"
elif(marks>=80 and marks<90):
    grade="B"
elif(marks>=70 and marks<80):
    grade="c"
else:
    grade="d"
print("grade of the student ->",grade)
# Out:
# enter the number 100
# grade of the student -> A

# %% [markdown]
# ## NESTING

# %%
age=34
if(age>=18):
    print("can drive")
else:
    print("can not drive")
# Out:
# can drive

# %%
age=17
if(age>=18):
    print("can drive")
else:
    print("can not drive")
# Out:
# can not drive

# %%
age=34
if(age>=18):
    if(age>=80):
        print("can not drive")
    else:
        print("can drive")
else:
   print("can not drive")
# Out:
# can drive

# %%
age=95
if(age>=18):
    if(age>=80):
        print("can not drive")
    else:
        print("can drive")
else:
    print("can not drive")
# Out:
# can not drive

# %% [markdown]
# ## LET'S PRACTICE

# %%
# write a program to check if a number entered by the user is odd or even.
num=int(input("enter a number"))
rem=num%2
if(rem==0):
    print("even")
else:
    print("odd")
# Out:
# enter a number 22
# even

# %%
num=int(input("enter a number"))
rem=num%2
if(rem==0):
    print("even")
else:
    print("odd")
# Out:
# enter a number 23
# odd

# %%
num=int(input("enter a number"))
if(num%2==0):
    print("even")
else:
    print("odd")
# Out:
# enter a number 10
# even

# %%
num=int(input("enter a number"))
if(num%2==0):
    print("even")
else:
    print("odd")
# Out:
# enter a number 11
# odd

# %%
# write a program to find the greatest of 3bnumbers entered by the user.
a=int(input("enter first number"))
b=int(input("enter second number"))
c=int(input("enter third number"))
if (a>=b and b>=c):
    print("first number is largest",a)
elif(b>=c):
    print("second number is largest",b)
else:
    print("third number is largest",c)
# Out:
# enter first number 99
# enter second number 89
# enter third number 79
# first number is largest 99

# %%
a=int(input("enter first number"))
b=int(input("enter second number"))
c=int(input("enter third number"))
if (a>=b and b>=c):
    print("first number is largest",a)
elif(b>=c):
    print("second number is largest",b)
else:
    print("third number is largest",c)
# Out:
# enter first number 11
# enter second number 12
# enter third number 13
# third number is largest 13

# %%
a=int(input("enter first number"))
b=int(input("enter second number"))
c=int(input("enter third number"))
if (a>=b and b>=c):
    print("first number is largest",a)
elif(b>=c):
    print("second number is largest",b)
else:
    print("third number is largest",c)
# Out:
# enter first number 9
# enter second number 10
# enter third number 7
# second number is largest 10

# %%
# write a program to check if a  number is a multiple of 7 or not.
x=int(input("enter a number"))
if(x%7==0):
    print("multiple of 7")
else:
    print("not a multiple")
# Out:
# enter a number 14
# multiple of 7

# %%
x=int(input("enter a number"))
if(x%7==0):
    print("multiple of 7")
else:
    print("not a multiple")
# Out:
# enter a number 11
# not a multiple

# %%
x = "A AM STUDYING PYTHON FROM APNA COLLEGE"
str=x.capitalize()
print(str)
# Out:
# A am studying python from apna college

# %%
y = "A am studying python from apna college"
z = y.capitalize()
print(z)
# Out:
# A am studying python from apna college

# %%
str1="madhurima"
print(str1)
print(type(str1))
# Out:
# madhurima
# <class 'str'>
